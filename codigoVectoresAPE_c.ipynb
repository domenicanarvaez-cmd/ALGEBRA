# %% [markdown]
# <a href="https://colab.research.google.com/github/domenicanarvaez-cmd/ALGEBRA/blob/main/codigoVectoresAPE_c.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
from datetime import date

# Definición de vectores en R3
v1 = [2, 3, 6]
v2 = [1, 4, 2]

print("Vector v1:", v1)
print("Vector v2:", v2)

# 1. Suma de vectores
suma = [v1[i] + v2[i] for i in range(3)]
print("\nSuma v1 + v2 =", suma)

# 2. Resta de vectores
resta = [v1[i] - v2[i] for i in range(3)]
print("Resta v1 - v2 =", resta)

# 3. Multiplicación por un escalar
escalar = 3
producto_escalar = [escalar * x for x in v1]
print(f"Multiplicación de v1 por el escalar {escalar} =", producto_escalar)

# 4. Producto punto
producto_punto = sum(v1[i] * v2[i] for i in range(3))
print("Producto punto v1 · v2 =", producto_punto)

# 5. Magnitud de un vector
magnitud_v1 = math.sqrt(sum(x**2 for x in v1))
print("Magnitud de v1 =", magnitud_v1)

# 5. Magnitud de un vector
magnitud_v1 = math.sqrt(sum(x**2 for x in v1))
print("Magnitud de v1 =", magnitud_v1)

# Personal Data
today = date.today()
nombres = "Domenica Brigeeth Narvaez Rivas" # Using the variable from kernel state
carrera = "Ingienería en Computación" # Using the variable from kernel state
ciclo = "1° 'A'" # Placeholder for the user to fill

print()
print(f"Datos:")
print(f"Nombre: {nombres}")
print(f"Fecha: {today}")
print(f"Carrera: {carrera}")
print(f"Ciclo: {ciclo}")
# Out:
# Vector v1: [2, 3, 6]
# Vector v2: [1, 4, 2]
#
# Suma v1 + v2 = [3, 7, 8]
# Resta v1 - v2 = [1, -1, 4]
# Multiplicación de v1 por el escalar 3 = [6, 9, 18]
# Producto punto v1 · v2 = 26
# Magnitud de v1 = 7.0
# Magnitud de v1 = 7.0
#
# Datos:
# Nombre: Domenica Brigeeth Narvaez Rivas
# Fecha: 2026-02-01
# Carrera: Ingienería en Computación
# Ciclo: 1° 'A'
